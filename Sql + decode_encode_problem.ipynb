# %% [markdown]
# # 寫入Sqlite

# %%
html_doc = """
<html><head><title>The Dormouse's story</title></head>
<body>
<p class="title">
    <b>The Dormouse's story</b>
</p>
<p class="story">
    Once upon a time there were three little sisters; and their names were
    <a href="http://example.com/elsie" class="sister" id="link1">Elsie</a>,
    <a href="http://example.com/lacie" class="sister" id="link2">Lacie</a> and
    <a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>;
    and they lived at the bottom of a well.
</p>
<p class="story">
    ...
</p>
"""
from bs4 import BeautifulSoup
soup = BeautifulSoup(html_doc, 'html.parser')
#print(soup.prettify())
soup.title
# <title>The Dormouse's story</title>

soup.title.name
# u'title'

soup.title.string
# u'The Dormouse's story'

#soup.title.parent.name
# u'head'

#soup.p
# <p class="title"><b>The Dormouse's story</b></p>

#soup.p['class']
# u'title'

#soup.a
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>

#soup.find_all('a')
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>,
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]

#soup.find(id="link3")
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>
# Out:
# u"The Dormouse's story"

# %%
import sqlite3
db = sqlite3.connect('test.sqlite')
db.close()

# %%
import sqlite3
db = sqlite3.connect('test.sqlite')
cur = db.cursor()
cur.execute('''CREATE TABLE IF NOT EXISTS Tender_awards(
                id INTEGER PRIMARY KEY,
                pkAtmMain TEXT,
                procuring_entity TEXT,
                entity_code TEXT,
                attr_of_procurement TEXT,
                opening_date DATETIME,
                procurement_type TEXT,
                tender_awarding_type TEXT,
                project_type TEXT,
                subject_of_procurement TEXT,
                job_number TEXT,
                budget_value BIGINTEGER,
                attr_of_tender_awarding TEXT,
                floor_price_value BIGINTEGER,
                tender_awarding_announce_date DATETIME,
                tender_awarding_date DATETIME,
                total_tender_awarding_value BIGINTEGER
                )''')
db.close()

# %%
import sqlite3

con = sqlite3.connect("test.sqlite") 

cur = con.cursor() 
cur.execute("DROP TABLE IF EXISTS PhoneAddress")  # Drop Table If Exisits 
cur.execute("CREATE TABLE PhoneAddress(phone CHAR(10) PRIMARY KEY, address TEXT, name TEXT unique, age INT NOT NULL)") 
cur.execute("INSERT INTO PhoneAddress VALUES('0912173381','United State','Jhon Doe',53)") 
cur.execute("INSERT INTO PhoneAddress VALUES('0928375018','Tokyo Japan','MuMu Cat',6)") 
cur.execute("INSERT INTO PhoneAddress VALUES('0957209108','Taipei','Richard',29)") 
con.commit()
#cur.execute("SELECT phone,address FROM PhoneAddress") 
#data = cur.fetchall() 
#    for rec in data: 
#        print rec[0], rec[1] 
con.close()

# %%
import sqlite3

con = sqlite3.connect("test.sqlite") 

cur = con.cursor() 

cur.execute("SELECT phone,address FROM PhoneAddress") 
data = cur.fetchone() # fetch one row at a time
print data
data2 = cur.fetchone()
print data2

con.close()
# Out:
# (u'0912173381', u'United State')
# (u'0928375018', u'Tokyo Japan')

# %%
import sqlite3

con = sqlite3.connect("test.sqlite") 

cur = con.cursor() 

cur.execute("SELECT phone,address FROM PhoneAddress") 
data = cur.fetchone() 
print data
data2 = cur.fetchall() # fetch all rows at a time
print data2
con.close()
# Out:
# (u'0912173381', u'United State')
# [(u'0928375018', u'Tokyo Japan'), (u'0957209108', u'Taipei')]

# %%
import requests
from bs4 import BeautifulSoup
url = 'https://www.flyingv.cc/type/online'
res = requests.get(url)
soup = BeautifulSoup(res.text)
list_item = soup.select('.portfolio-content ')
for li in list_item:
#    print li
   print li.select('.unit-owner')[0].text#.strip()#.text.strip()
    #print  li.select('h5')[0].text+'\n',li.select('.unit-owner')[0].text.strip().encode('utf-8')+'\n', li.select('.unit-money')[0].text
# Out:
#                 提案者： Yuan Chu Lin
#
#
#                 提案者： Perun Tech
#
#
#                 提案者： 加泓優
#
#
#                 提案者： Inion Design Associates
#
#
#                 提案者： 好福食研室
#
#
#                 提案者： 何岡秩
#
#
#                 提案者： jrthomann
#
#
#                 提案者： SinapisTek Inc.
#
#
#                 提案者： Mustache Boy
#
#
#                 提案者： 俬儲空間
#
#
#                 提案者： 23號半
#
#
#                 提案者： 輔仁大學坦尚尼亞醫療志工團
#
#
#                 提案者： ZINIZ
#
#
#                 提案者： Blue Seeds
#
#
#                 提案者： 生祥樂隊
#
#
#                 提案者： 中原建築52屆畢業班全體同學
#
#
#                 提案者： 台灣同志諮詢熱線
#
#
#                 提案者： 果物配
#
#
#                 提案者： Reise 米膚保養
#
#
#                 提案者： 南拳媽媽
#
#
#                 提案者： 薄伽梵
#
#
#                 提案者： 樂居
#
#
#                 提案者： 圓園方坊
#
#
#                 提案者： Irene Lee
#
#
#                 提案者： 陳愷徽
#
#
#                 提案者： lzx
#
#
#                 提案者： 鬼娃劇團
#
#
#                 提案者： 社團法人台灣福氣社區關懷協會
#
#
# ...

# %% [markdown]
# ### 開啟一個HTTP伺服器
#
# - %ls  檢視目前所在
#
# - cd   #先移動到資料夾
#
# - python -m SimpleHTTPServer 8888
#
# http://goo.gl/rIWACB   #網路教學

# %% [markdown]
# ### - request模擬get request post 等瀏覽器動作

# %%
import requests
res = requests.get('https://www.ptt.cc/bbs/Food/index.html')
print res.text
# Out:
# <!DOCTYPE html>
# <html>
# 	<head>
# 		<meta charset="utf-8">
#
#
# <meta name="viewport" content="width=device-width">
#
# <title>看板 Food 文章列表 - 批踢踢實業坊</title>
#
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/v2.14/bbs-common.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/v2.14/bbs.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/v2.14/pushstream.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/v2.14/bbs-print.css" media="print">
#
#
# <script src="//ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js"></script>
# <script src="//images.ptt.cc/v2.14/bbs.js"></script>
#
#
#
#
# <script type="text/javascript">
#
#   var _gaq = _gaq || [];
#   _gaq.push(['_setAccount', 'UA-32365737-1']);
#   _gaq.push(['_setDomainName', 'ptt.cc']);
#   _gaq.push(['_trackPageview']);
#
#   (function() {
# ...

# %% [markdown]
# ### - BeautifulSoup 濾掉標籤直接呈現文字

# %%
from bs4 import BeautifulSoup 
soup = BeautifulSoup(res.text)
for head in soup.select('.r-ent a'):
    #print head.text
    #if len(head.text.split())>0:
        #print head.text.split()[0]
    if '公告'.decode('utf-8') in head.text:   
        print head.text
# Out:
# [公告] Food板 板規 V3.8
# [公告] 發文請在標題加上地區及提供地址電話。^^
# [公告] 文章被刪除者請洽精華區的資源回收桶
# [公告] 板規16發文標題須含餐廳店名之調整

# %% [markdown]
# ### '公告'.decode('utf-8')  如果'公告'用utf-8解析
#
# - http://www.runoob.com/python/att-string-decode.html
# - decode #解開鎖頭的KEY
# - encode #無法窺探的鎖頭
# - 超詳細講解 http://python.ez2learn.com/basic/unicode.html

# %%
str = "this is string example....wow!!!";
str = str.encode('base64','strict');

print "Encoded String: " + str;
print "Decoded String: " + str.decode('base64','strict')
# Out:
# Encoded String: dGhpcyBpcyBzdHJpbmcgZXhhbXBsZS4uLi53b3chISE=
#
# Decoded String: this is string example....wow!!!

# %%
f = open('test.txt', 'r')
b_str = f.read()
f.close()
print b_str.decode('utf-8')  # 自行判斷標準輸出編碼
print b_str.decode('utf-8').encode('big5') # 標準輸出編碼為 big5
# Out:
# ﻿測試
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# <ipython-input-71-3a76334089b5> in <module>()
#       3 f.close()
#       4 print b_str.decode('utf-8')  # 自行判斷標準輸出編碼
# ----> 5 print b_str.decode('utf-8').encode('big5') # 標準輸出編碼為 big5
#
# UnicodeEncodeError: 'big5' codec can't encode character u'\ufeff' in position 0: illegal multibyte sequence

# %%
# -*- coding: utf8 -*-
msg = u'今天天氣真好'
print msg
print u'字數:', len(msg)
# Out:
# 今天天氣真好
# 字數: 6

# %%
# -*- coding: utf8 -*-
msg = '今天天氣真好'
print msg
print '字數:', len(msg)
# Out:
# 今天天氣真好
# 字數: 18

# %%
# -*- coding: utf8 -*-
msg = u'今天天氣真好'
encoded = msg.encode('utf8')
print repr(encoded)
# Out:
# '\xe4\xbb\x8a\xe5\xa4\xa9\xe5\xa4\xa9\xe6\xb0\xa3\xe7\x9c\x9f\xe5\xa5\xbd'

# %%
# -*- coding: utf8 -*-
encoded = '\xe4\xbb\x8a\xe5\xa4\xa9\xe5\xa4\xa9\xe6\xb0\xa3\xe7\x9c\x9f\xe5\xa5\xbd'
msg = encoded.decode('utf8')
print msg
# Out:
# 今天天氣真好
